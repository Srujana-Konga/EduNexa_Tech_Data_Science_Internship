# %% [markdown]
# ## Task-1: Exploring a dataset
# Choose a dataset of your interest (e.g., from Kaggle) and explore its basic characteristics. Use Python with libraries like Pandas to load the dataset, check for missing values, and display summary statistics.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the dataset

# %%
file_path = r"E:\EduNexa Tech Datasets\auction.csv"
data = pd.read_csv(file_path)
data
# Out:
#       Unnamed: 0       Country                Player  \
# 0              0        Guyana  Christopher Barnwell
# 1              1  South Africa           Johan Botha
# 2              2     Australia      Daniel Christian
# 3              3     Australia        Michael Clarke
# 4              4     Australia   Nathan Coulter-Nile
# ...          ...           ...                   ...
# 1047        1047       England              Joe Root
# 1048        1048    Bangladesh       Shakib al Hasan
# 1049        1049         India          Abdul Basith
# 1050        1050       England              Joe Root
# 1051        1051    Bangladesh       Shakib al Hasan
#
#                              Team  Base price Winning bid  Year
# 0     Royal Challengers Bangalore        30.5        30.5  2013
# 1                Delhi Daredevils       183.0       274.5  2013
# 2     Royal Challengers Bangalore        61.0          61  2013
# 3             Pune Warriors India       244.0         244  2013
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Player', 'Team', 'Base price', 'Winning bid',
#        'Year'],
#       dtype='object')

# %%
data.shape
# Out:
# (1052, 7)

# %%
data.head()
# Out:
#    Unnamed: 0       Country                Player  \
# 0           0        Guyana  Christopher Barnwell
# 1           1  South Africa           Johan Botha
# 2           2     Australia      Daniel Christian
# 3           3     Australia        Michael Clarke
# 4           4     Australia   Nathan Coulter-Nile
#
#                           Team  Base price Winning bid  Year
# 0  Royal Challengers Bangalore        30.5        30.5  2013
# 1             Delhi Daredevils       183.0       274.5  2013
# 2  Royal Challengers Bangalore        61.0          61  2013
# 3          Pune Warriors India       244.0         244  2013
# 4               Mumbai Indians        61.0       274.5  2013

# %%
data.tail()
# Out:
#       Unnamed: 0      Country           Player                   Team  \
# 1047        1047      England         Joe Root       Rajasthan Royals
# 1048        1048   Bangladesh  Shakib al Hasan  Kolkata Knight Riders
# 1049        1049        India     Abdul Basith       Rajasthan Royals
# 1050        1050      England         Joe Root       Rajasthan Royals
# 1051        1051   Bangladesh  Shakib al Hasan  Kolkata Knight Riders
#
#       Base price Winning bid  Year
# 1047       100.0         100  2023
# 1048       150.0         150  2023
# 1049        20.0          20  2023
# 1050       100.0         100  2023
# 1051       150.0         150  2023

# %%
data.describe()
# Out:
#         Unnamed: 0   Base price        Year
# count  1052.000000  1052.000000  1052.00000
# mean    525.500000    65.252091  2018.31654
# std     303.830545    63.278684     3.15770
# min       0.000000    10.000000  2013.00000
# 25%     262.750000    20.000000  2016.00000
# 50%     525.500000    30.000000  2018.00000
# 75%     788.250000   100.000000  2022.00000
# max    1051.000000   244.000000  2023.00000

# %%
data.dtypes
# Out:
# Unnamed: 0       int64
# Country         object
# Player          object
# Team            object
# Base price     float64
# Winning bid     object
# Year             int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Country        0
# Player         0
# Team           0
# Base price     0
# Winning bid    0
# Year           0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Unnamed: 0     0
# Country        0
# Player         0
# Team           0
# Base price     0
# Winning bid    0
# Year           0
# dtype: int64

# %%
df = pd.DataFrame(data)

# %%
group_data = data.sort_values(by=['Country'])
group_data
# Out:
#       Unnamed: 0               Country            Player  \
# 955          955           Afghanistan     Mohammad Nabi
# 937          937           Afghanistan  Fazalhaq Farooqi
# 833          833           Afghanistan        Noor Ahmad
# 1043        1043           Afghanistan     Naveen-ul-Haq
# 922          922             Australia      Matthew Wade
# ...          ...                   ...               ...
# 101          101   Trinidad and Tobago     Samuel Badree
# 138          138   Trinidad and Tobago      Kevon Cooper
# 499          499   Trinidad and Tobago        Evin Lewis
# 405          405  United Arab Emirates       Chirag Suri
# 87            87              Zimbabwe    Brendan Taylor
#
#                        Team  Base price Winning bid  Year
# 955   Kolkata Knight Riders       100.0         100  2022
# 937     Sunrisers Hyderabad        50.0          50  2022
# 833          Gujarat Titans        30.0          30  2022
# ...

# %%
team_data = data.sort_values(by = ['Team'])
team_data
# Out:
#      Unnamed: 0       Country              Player                 Team  \
# 848         848         India         Shivam Dube  Chennai Super Kings
# 198         198         India     Eklavya Dwivedi  Chennai Super Kings
# 463         463         India         Karn Sharma  Chennai Super Kings
# 923         923         India    C. Hari Nishanth  Chennai Super Kings
# 925         925         India  Narayan Jagadeesan  Chennai Super Kings
# ..          ...           ...                 ...                  ...
# 62           62         India          Naman Ojha  Sunrisers Hyderabad
# 255         255         India       Hanuma Vihari  Sunrisers Hyderabad
# 937         937   Afghanistan    Fazalhaq Farooqi  Sunrisers Hyderabad
# 251         251       England         Ravi Bopara  Sunrisers Hyderabad
# 429         429   New Zealand     Kane Williamson  Sunrisers Hyderabad
#
#      Base price Winning bid  Year
# 848        50.0         400  2022
# 198        10.0          10  2015
# ...

# %%
data['Base price'].astype(int)
# Out:
# 0        30
# 1       183
# 2        61
# 3       244
# 4        61
#        ...
# 1047    100
# 1048    150
# 1049     20
# 1050    100
# 1051    150
# Name: Base price, Length: 1052, dtype: int32

# %% [markdown]
# ## Finding the highest base price team in auction

# %%
data.groupby('Team')['Base price'].sum().sort_values(ascending = False)
# Out:
# Team
# Royal Challengers Bangalore    8505.5
# Kolkata Knight Riders          8186.0
# Sunrisers Hyderabad            7976.7
# Chennai Super Kings            6565.8
# Rajasthan Royals               6514.2
# Mumbai Indians                 6488.5
# Kings XI Punjab                5597.5
# Delhi Daredevils               5419.5
# Delhi Capitals                 3710.0
# Punjab Kings                   2225.0
# Lucknow Super Giants           2070.0
# Gujarat Titans                 2020.0
# Gujarat Lions                  1200.0
# Rising Pune Supergiant         1100.0
# Rising Pune Supergiants         470.0
# Pune Warriors India             396.5
# Delhi Dardevils                 200.0
# Name: Base price, dtype: float64

# %% [markdown]
# ## Finding the country with highest base price

# %%
data.groupby('Country')['Base price'].sum().sort_values(ascending = False)
# Out:
# Country
# India                   20766.5
# Australia               10831.7
#  India                   8745.0
# England                  5255.0
# South Africa             3572.9
#  England                 3065.0
# New Zealand              2682.5
#  Australia               2135.0
#  West Indies             2100.0
#  New Zealand             1675.0
#  South Africa            1410.0
# Sri Lanka                1126.4
# Trinidad and Tobago       895.5
# Bangladesh                650.0
# Barbados                  648.2
# Jamaica                   585.0
# Afghanistan               550.0
#  Bangladesh               550.0
#  Sri Lanka                300.0
# Saint Lucia               291.0
#  Afghanistan              230.0
# Guyana                    220.5
# Netherlands               100.0
#  Namibia                  100.0
#  Zimbabwe                  50.0
#  Ireland                   50.0
# Zimbabwe                   30.0
# Nepal                      20.0
# United Arab Emirates       10.0
# ...
